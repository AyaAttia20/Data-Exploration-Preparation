# %% [markdown]
# ## Preferred American University

# %% [markdown]
# ### Reading the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel('IPEDS_data.xlsx')
data.head()
# Out:
#    ID number                                 Name  year    ZIP code  \
# 0     100654             Alabama A & M University  2013       35762
# 1     100663  University of Alabama at Birmingham  2013  35294-0110
# 2     100690                   Amridge University  2013  36117-3553
# 3     100706  University of Alabama in Huntsville  2013       35899
# 4     100724             Alabama State University  2013  36104-0271
#
#                               Highest degree offered        County name  \
# 0             Doctor's degree - research/scholarship     Madison County
# 1  Doctor's degree - research/scholarship and pro...   Jefferson County
# 2  Doctor's degree - research/scholarship and pro...  Montgomery County
# 3  Doctor's degree - research/scholarship and pro...     Madison County
# 4  Doctor's degree - research/scholarship and pro...  Montgomery County
#
#    Longitude location of institution  Latitude location of institution  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Columns: 145 entries, ID number to Endowment assets (year end) per FTE enrollment (FASB)
# dtypes: float64(116), int64(2), object(27)
# memory usage: 1.7+ MB

# %%
data.shape
# Out:
# (1534, 145)

# %%
data.isna().sum()
# Out:
# ID number                                                   0
# Name                                                        0
# year                                                        0
# ZIP code                                                    0
# Highest degree offered                                      0
#                                                          ...
# Percent of freshmen receiving student loan aid             42
# Percent of freshmen receiving federal student loans        42
# Percent of freshmen receiving other loan aid               42
# Endowment assets (year end) per FTE enrollment (GASB)    1018
# Endowment assets (year end) per FTE enrollment (FASB)     574
# Length: 145, dtype: int64

# %% [markdown]
# ##### Drop the most column has missing values

# %%
data=data.drop(['ID number','Endowment assets (year end) per FTE enrollment (GASB)','Endowment assets (year end) per FTE enrollment (FASB)'],axis=1)
data.head()
# Out:
#                                   Name  year    ZIP code  \
# 0             Alabama A & M University  2013       35762
# 1  University of Alabama at Birmingham  2013  35294-0110
# 2                   Amridge University  2013  36117-3553
# 3  University of Alabama in Huntsville  2013       35899
# 4             Alabama State University  2013  36104-0271
#
#                               Highest degree offered        County name  \
# 0             Doctor's degree - research/scholarship     Madison County
# 1  Doctor's degree - research/scholarship and pro...   Jefferson County
# 2  Doctor's degree - research/scholarship and pro...  Montgomery County
# 3  Doctor's degree - research/scholarship and pro...     Madison County
# 4  Doctor's degree - research/scholarship and pro...  Montgomery County
#
#    Longitude location of institution  Latitude location of institution  \
# 0                         -86.568502                         34.783368
# ...

# %%
list(data.columns)
# Out:
# ['Name',
#  'year',
#  'ZIP code',
#  'Highest degree offered',
#  'County name',
#  'Longitude location of institution',
#  'Latitude location of institution',
#  'Religious affiliation',
#  'Offers Less than one year certificate',
#  'Offers One but less than two years certificate',
#  "Offers Associate's degree",
#  'Offers Two but less than 4 years certificate',
#  "Offers Bachelor's degree",
#  'Offers Postbaccalaureate certificate',
#  "Offers Master's degree",
#  "Offers Post-master's certificate",
#  "Offers Doctor's degree - research/scholarship",
#  "Offers Doctor's degree - professional practice",
#  "Offers Doctor's degree - other",
#  'Offers Other degree',
#  'Applicants total',
#  'Admissions total',
#  'Enrolled total',
#  'Percent of freshmen submitting SAT scores',
#  'Percent of freshmen submitting ACT scores',
#  'SAT Critical Reading 25th percentile score',
#  'SAT Critical Reading 75th percentile score',
#  'SAT Math 25th percentile score',
# ...

# %% [markdown]
# #### show the correlation between feature

# %%
data.corr(method='kendall')
# Out:
#                                                     year  \
# year                                                 1.0
# Longitude location of institution                    NaN
# Latitude location of institution                     NaN
# Applicants total                                     NaN
# Admissions total                                     NaN
# ...                                                  ...
# Percent of freshmen receiving state/local grant...   NaN
# Percent of freshmen receiving institutional gra...   NaN
# Percent of freshmen receiving student loan aid       NaN
# Percent of freshmen receiving federal student l...   NaN
# Percent of freshmen receiving other loan aid         NaN
#
#                                                     Longitude location of institution  \
# year                                                                              NaN
# Longitude location of institution                                            1.000000
# ...

# %% [markdown]
# ### Do universities with a high number of applications are the preferred ones by students? in other words, could the number of applications tell us that a university is one of the most preferred by students?

# %%
high_unver_app=data.groupby('Name')['Applicants total'].max().sort_values(ascending=False)
print(high_unver_app[:5])
# Out:
# Name
# University of California-Los Angeles    72676.0
# University of California-Berkeley       61717.0
# University of California-San Diego      60832.0
# New York University                     57845.0
# University of California-Irvine         56515.0
# Name: Applicants total, dtype: float64

# %%
df_applicants=pd.DataFrame(high_unver_app[:5])
df_applicants
# Out:
#                                       Applicants total
# Name
# University of California-Los Angeles           72676.0
# University of California-Berkeley              61717.0
# University of California-San Diego             60832.0
# New York University                            57845.0
# University of California-Irvine                56515.0

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df_applicants['Applicants total'],y=df_applicants.index)
# Out:
# <Axes: xlabel='Applicants total', ylabel='Name'>

# %% [markdown]
# #### Insight:
# The Top_5 Universities with a high number of applications are [  University of California-Los Angele,University of California-Berkeley,University of California-San Diego,New York University,University of California-Irvine]

# %% [markdown]
# #### show the total enrollment in each university

# %%
enrol=data.groupby('Name')['Enrolled total'].max().sort_values(ascending=False)[:5]
enrol
# Out:
# Name
# Texas A & M University-College Station       10241.0
# Michigan State University                     8061.0
# Pennsylvania State University-Main Campus     7649.0
# Indiana University-Bloomington                7604.0
# University of Arizona                         7401.0
# Name: Enrolled total, dtype: float64

# %%
df_enrol=pd.DataFrame(enrol)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df_enrol['Enrolled total'],y=df_enrol.index)
# Out:
# <Axes: xlabel='Enrolled total', ylabel='Name'>

# %% [markdown]
# ### Insight:
# The universities that have higher number of applications, don't have higher enrolled so universities with a high number of applications are't the preferred ones by students.

# %% [markdown]
# ### Do students prefer universities that have a high rate of admission?, in other words, do students prefer a university where it is easier for them to be admitted?.

# %%
high_unver_add=data.groupby('Name')['Admissions total'].max().sort_values(ascending=False)
print(high_unver_add[:5])
# Out:
# Name
# Drexel University                            35815.0
# Northern Arizona University                  31057.0
# St John's University-New York                27449.0
# Indiana University-Bloomington               27300.0
# Pennsylvania State University-Main Campus    25772.0
# Name: Admissions total, dtype: float64

# %%
df_high_admiss=pd.DataFrame(high_unver_add[:5])

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df_high_admiss['Admissions total'],y=df_high_admiss.index)
# Out:
# <Axes: xlabel='Admissions total', ylabel='Name'>

# %% [markdown]
# #### Insight:
# The Top_5 universities  with high Admissions Total are [ Drexel University,
# Northern Arizona Universitym,
# St John's University-New York,
# Indiana University-Bloomington]

# %% [markdown]
# ### Insight:
# The universities that have higher number of admission, don't have higher enrolled so universities with a high number of applications are't the preferred ones by students.

# %% [markdown]
# ### Do students prefer public or private universities?

# %%
data['Control of institution'].unique()
# Out:
# array(['Public', 'Private not-for-profit'], dtype=object)

# %%
sns.histplot(data['Control of institution'])
plt.show()

# %%
data['Control of institution'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Insight:
#  private universities more than public

# %%
sns.barplot(x= data['Control of institution'], y=data['Applicants total'])
# Out:
# <Axes: xlabel='Control of institution', ylabel='Applicants total'>

# %% [markdown]
# ### Insight:
# the public university has higher number of applicants

# %%
sns.barplot(x= data['Control of institution'], y=data['Admissions total'])
# Out:
# <Axes: xlabel='Control of institution', ylabel='Admissions total'>

# %% [markdown]
# ### Insight:
# the public university has higher number of admissions

# %% [markdown]
# ### Do students prefer universities with low tuition and fees?

# %%
data['Tuition and fees, 2013-14'].isna().sum()
# Out:
# 37

# %%
data['Tuition and fees, 2013-14'].fillna(value=data['Tuition and fees, 2013-14'].mean(), inplace=True)

# %%
data['Tuition and fees, 2013-14'].isna().sum()
# Out:
# 0

# %%
unver_tutition=data.groupby('Name')['Tuition and fees, 2013-14'].min().sort_values(ascending=True)
top_10_low_tut=unver_tutition[:10]
print(top_10_low_tut)
# Out:
# Name
# United States Merchant Marine Academy      1032.0
# Great Basin College                        2700.0
# West Virginia University at Parkersburg    2712.0
# St Petersburg College                      3232.0
# Langston University                        3815.0
# Brigham Young University-Idaho             3850.0
# Dalton State College                       3910.0
# New Mexico Highlands University            4000.0
# Northern New Mexico College                4060.0
# The University of Montana-Western          4141.0
# Name: Tuition and fees, 2013-14, dtype: float64

# %%
df_low_tut=pd.DataFrame(top_10_low_tut)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df_low_tut['Tuition and fees, 2013-14'],y=df_low_tut.index)
# Out:
# <Axes: xlabel='Tuition and fees, 2013-14', ylabel='Name'>

# %%
print(df_low_tut)
print("-----------------------------------------------------------------------------")
print(df_applicants)
print("-----------------------------------------------------------------------------")
print(df_enrol)
# Out:
#                                          Tuition and fees, 2013-14
# Name
# United States Merchant Marine Academy                       1032.0
# Great Basin College                                         2700.0
# West Virginia University at Parkersburg                     2712.0
# St Petersburg College                                       3232.0
# Langston University                                         3815.0
# Brigham Young University-Idaho                              3850.0
# Dalton State College                                        3910.0
# New Mexico Highlands University                             4000.0
# Northern New Mexico College                                 4060.0
# The University of Montana-Western                           4141.0
# -----------------------------------------------------------------------------
#                                       Applicants total
# Name
# University of California-Los Angeles           72676.0
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df_applicants['Applicants total'],y=df_applicants.index)
plt.figure(figsize=(10,5))
sns.barplot(x=df_enrol['Enrolled total'],y=df_enrol.index)
plt.figure(figsize=(10,5))
sns.barplot(x=df_low_tut['Tuition and fees, 2013-14'],y=df_low_tut.index)
# Out:
# <Axes: xlabel='Tuition and fees, 2013-14', ylabel='Name'>

# %% [markdown]
# Insight:
# the universities with high applicants and the universities with high admission are't in the low Tuition and fees top ten universities

# %%
publicity_univ=data[['Name','Control of institution']]
publicity_univ
# Out:
#                                                Name  Control of institution
# 0                          Alabama A & M University                  Public
# 1               University of Alabama at Birmingham                  Public
# 2                                Amridge University  Private not-for-profit
# 3               University of Alabama in Huntsville                  Public
# 4                          Alabama State University                  Public
# ...                                             ...                     ...
# 1529   University of South Florida-Sarasota-Manatee                  Public
# 1530                           The Kingâ€™s College  Private not-for-profit
# 1531                       Ottawa University-Online  Private not-for-profit
# 1532                   Providence Christian College  Private not-for-profit
# 1533  Polytechnic University of Puerto Rico-Orlando  Private not-for-profit
#
# [1534 rows x 2 columns]

# %%
tot_df=pd.concat([publicity_univ,data[['Applicants total','Admissions total','Enrolled total','Tuition and fees, 2013-14']]],axis=1)
tot_df.sort_values(by=['Enrolled total','Tuition and fees, 2013-14'],ascending=[False,True])
# Out:
#                                                  Name  Control of institution  \
# 1309           Texas A & M University-College Station                  Public
# 606                         Michigan State University                  Public
# 1133        Pennsylvania State University-Main Campus                  Public
# 359                    Indiana University-Bloomington                  Public
# 34                              University of Arizona                  Public
# ...                                               ...                     ...
# 1517  Harrisburg University of Science and Technology  Private not-for-profit
# 975                             Heidelberg University  Private not-for-profit
# 379                            Briar Cliff University  Private not-for-profit
# 732                             Sierra Nevada College  Private not-for-profit
# 378                                    Wabash College  Private not-for-profit
#
# ...

# %% [markdown]
# ### Insight:
# from the observations, the universities has high Enrolled total  with low Tuition,so students prefer universities with low tuition and fees.

# %% [markdown]
# ### Do students prefer a university for its low on-campus cost of living?

# %%
'Total price for in-state students living on campus 2013-14',
'Total price for out-of-state students living on campus 2013-14',
# Out:
# ('Total price for out-of-state students living on campus 2013-14',)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=data['Applicants total'],y=data['Total price for in-state students living on campus 2013-14'])
plt.subplot(1, 2, 2)
sns.scatterplot(x=data['Enrolled total'],y=data['Total price for in-state students living on campus 2013-14'],color='m')
# Out:
# <Axes: xlabel='Enrolled total', ylabel='Total price for in-state students living on campus 2013-14'>

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=data['Applicants total'],y=data['Total price for out-of-state students living on campus 2013-14'],color='r')
plt.subplot(1, 2, 2)
sns.scatterplot(x=data['Enrolled total'],y=data['Total price for out-of-state students living on campus 2013-14'],color='c')
# Out:
# <Axes: xlabel='Enrolled total', ylabel='Total price for out-of-state students living on campus 2013-14'>

# %%
tot_df=pd.concat([tot_df,data[['Total price for in-state students living on campus 2013-14','Total price for out-of-state students living on campus 2013-14']]],axis=1)

# %%
tot_df
# Out:
#                                                Name  Control of institution  \
# 0                          Alabama A & M University                  Public
# 1               University of Alabama at Birmingham                  Public
# 2                                Amridge University  Private not-for-profit
# 3               University of Alabama in Huntsville                  Public
# 4                          Alabama State University                  Public
# ...                                             ...                     ...
# 1529   University of South Florida-Sarasota-Manatee                  Public
# 1530                           The Kingâ€™s College  Private not-for-profit
# 1531                       Ottawa University-Online  Private not-for-profit
# 1532                   Providence Christian College  Private not-for-profit
# 1533  Polytechnic University of Puerto Rico-Orlando  Private not-for-profit
#
# ...

# %%
tot_df.sort_values(by=['Enrolled total','Total price for in-state students living on campus 2013-14','Total price for out-of-state students living on campus 2013-14'],ascending=[False,True,True])
# Out:
#                                                Name  Control of institution  \
# 1309         Texas A & M University-College Station                  Public
# 606                       Michigan State University                  Public
# 1133      Pennsylvania State University-Main Campus                  Public
# 359                  Indiana University-Bloomington                  Public
# 34                            University of Arizona                  Public
# ...                                             ...                     ...
# 1524                    The Robert B Miller College  Private not-for-profit
# 1527    Averett University-Non-Traditional Programs  Private not-for-profit
# 1528                                  LIU Riverhead  Private not-for-profit
# 1531                       Ottawa University-Online  Private not-for-profit
# 1533  Polytechnic University of Puerto Rico-Orlando  Private not-for-profit
#
# ...

# %% [markdown]
# ### Insight:
# from these all observation ,the number of enrolled is high with lower price either inside or outside university ,so the students prefer a university for its low on-campus cost of living

# %% [markdown]
# ### Do students prefer universities from highly populated state?

# %%
data['State abbreviation'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
plt.figure(figsize=(20,15))
sns.barplot(x= data['Enrolled total'], y=data['State abbreviation'])
# Out:
# <Axes: xlabel='Enrolled total', ylabel='State abbreviation'>

# %%
high_state_enrol=data.groupby('State abbreviation')['Enrolled total'].max().sort_values(ascending=False)
df_state_enrol=pd.DataFrame(high_state_enrol[:5])
df_state_enrol
# Out:
#                     Enrolled total
# State abbreviation
# Texas                      10241.0
# Michigan                    8061.0
# Pennsylvania                7649.0
# Indiana                     7604.0
# Arizona                     7401.0

# %%
df_state_enrol=df_state_enrol.reset_index()
df_state_enrol
# Out:
#   State abbreviation  Enrolled total
# 0              Texas         10241.0
# 1           Michigan          8061.0
# 2       Pennsylvania          7649.0
# 3            Indiana          7604.0
# 4            Arizona          7401.0

# %%
highly_populated_state = ['California', 'Florida', 'Texas', 'New York', 'Pennsylvania']

# %%
for st in highly_populated_state:
    if st in  df_state_enrol['State abbreviation'].values:
         print(st)
# Out:
# Texas
# Pennsylvania

# %% [markdown]
# ### Insight:
# from the observation ,It does not have to be one of the most populated states in order for more enrollled to occur.
# based on searching which highly populated state  and according to Enrolled total there is two states from the top 5 in enrolled total number and the rest states not highly populated.

# %% [markdown]
# ### Do students prefer a university based on the possibility of a higher, additional academic degree in the same university?

# %%
df_highest=pd.DataFrame(hg_degree)
df_highest=df_highest.reset_index()
# Out:
#                                                index  Highest degree offered
# 0                                    Master's degree                     587
# 1  Doctor's degree - research/scholarship and pro...                     311
# 2                                  Bachelor's degree                     282
# 3             Doctor's degree - research/scholarship                     201
# 4           Doctor's degree -  professional practice                     125
# 5                            Doctor's degree - other                      28

# %%
high_deg_df=pd.concat([data['Name'][:3],df_highest],axis=1)
high_deg_df
# Out:
#                                   Name  \
# 0             Alabama A & M University
# 1  University of Alabama at Birmingham
# 2                   Amridge University
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
#
#                                                index  Highest degree offered
# 0                                    Master's degree                     587
# 1  Doctor's degree - research/scholarship and pro...                     311
# 2                                  Bachelor's degree                     282
# 3             Doctor's degree - research/scholarship                     201
# 4           Doctor's degree -  professional practice                     125
# 5                            Doctor's degree - other                      28

# %%
high_enrol_df_=pd.concat([high_deg_df,data['Enrolled total'][:3]],axis=1)

# %%
high_enrol_df_
# Out:
#                                   Name  \
# 0             Alabama A & M University
# 1  University of Alabama at Birmingham
# 2                   Amridge University
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
#
#                                                index  Highest degree offered  \
# 0                                    Master's degree                     587
# 1  Doctor's degree - research/scholarship and pro...                     311
# 2                                  Bachelor's degree                     282
# 3             Doctor's degree - research/scholarship                     201
# 4           Doctor's degree -  professional practice                     125
# 5                            Doctor's degree - other                      28
#
#    Enrolled total
# 0          1104.0
# 1          1773.0
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN

# %% [markdown]
# #### Insight:
# The universities provide high acadamic degree has high number of enrollment.
